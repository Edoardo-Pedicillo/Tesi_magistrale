# %% [markdown]
# Training a qcgan with a gamma function with 6 parameters (1 layer)

# %%
from scipy.special import kl_div,rel_entr
import numpy as np
from matplotlib import pyplot
import quantum_classical_1Dgamma as qc

import tensorflow as tf
from matplotlib import pyplot
from qibo import gates, hamiltonians, models, set_backend, set_threads
# Out:
# [Qibo 0.1.6|INFO|2022-03-28 11:59:20]: Using numpy backend on /CPU:0
# [Qibo 0.1.6|WARNING|2022-03-28 11:59:20]: numpy backend uses `np.einsum` and supports CPU only. Consider installing the qibojit or qibotf backends for increased performance and to enable GPU acceleration.
# [Qibo 0.1.6|INFO|2022-03-28 11:59:20]: Using tensorflow backend on /device:CPU:0
# [Qibo 0.1.6|WARNING|2022-03-28 11:59:20]: `set_threads` is not supported by the tensorflow backend. Please use tensorflow's thread setters: `tf.config.threading.set_inter_op_parallelism_threads` or `tf.config.threading.set_intra_op_parallelism_threads` to switch the number of threads.

# %%
epochs=30000
d_loss = np.loadtxt(f"dloss_1Dgamma_1_3_1_10000_128_0.1_{epochs}", delimiter=' ')
g_loss= np.loadtxt(f"gloss_1Dgamma_1_3_1_10000_128_0.1_{epochs}", delimiter=' ')
#d_loss=d_loss[:5000]
#g_loss=g_loss[:5000]
pyplot.figure(figsize=(20, 7), dpi=80)
pyplot.plot(np.linspace(0, len(g_loss), len(g_loss)), g_loss, label='generator loss')
pyplot.plot(np.linspace(0, len(g_loss), len(g_loss)), d_loss, label='discriminator loss')
pyplot.legend()
pyplot.title("gamma 6 free parameters")
#pyplot.ylim(0.692,0.696)
#pyplot.xlim(0,1000)
pyplot.show()

# %%
def hamiltonian1():
        m0 = hamiltonians.Z(1).matrix
        ham = hamiltonians.Hamiltonian(1, m0)
        return ham
    
# number of qubits generator
nqubits = 1
# create hamiltonians
hamiltonian1 = hamiltonian1()

latent_dim=3
samples=2000
nqubits=1
layers=1
# create quantum generator
circuit = models.Circuit(nqubits)
for l in range(layers):
    for q in range(nqubits):
        circuit.add(gates.RY(q, 0))
        circuit.add(gates.RZ(q, 0))
for q in range(nqubits):
    circuit.add(gates.RY(q, 0))  

params = np.loadtxt(f"PARAMS_1Dgamma_1_3_1_10000_128_0.1_{epochs}", delimiter=' ', unpack='true')
#print(params,epochs)
params = tf.Variable(params)

x_fake1, y_fake = qc.generate_fake_samples(params, latent_dim, samples, circuit, nqubits, layers, hamiltonian1)

#x_fake,_= qc2.generate_fake_samples(params, latent_dim, samples)
fig, ax = pyplot.subplots(figsize = (14, 7))
s=qc.generate_training_real_samples(samples)
x_real1, y_real = qc.generate_real_samples(samples, s, 1000)

x_real1=x_real1
x_fake1=x_fake1
ax.set_yscale('log')
nbins=60
bins_real=pyplot.hist(x_real1, color='red', bins=nbins,label='real', alpha=0.5)
bins_fake=pyplot.hist(x_fake1.numpy(), bins=bins_real[1],color='blue', label='fake', alpha=0.5)

pyplot.legend()
pyplot.title("Distributions of fake and real generators")
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-bf6fe8d6def6> in <module>
#      26 params = tf.Variable(params)
#      27
# ---> 28 x_fake1, y_fake = qc.generate_fake_samples(params, latent_dim, samples, circuit, nqubits, layers, hamiltonian1)
#      29
#      30 #x_fake,_= qc2.generate_fake_samples(params, latent_dim, samples)
#
# ~/Scrivania/Tesi_magistrale/Codice/gamma_6_params/quantum_classical_1Dgamma.py in generate_fake_samples(params, latent_dim, samples, circuit, nqubits, layers, hamiltonian1)
#     113     for i in range(samples):
#     114         set_params(circuit, params, x_input, i, nqubits, layers, latent_dim)
# --> 115         circuit_execute = circuit.execute()
#     116         X.append(hamiltonian1.expectation(circuit_execute))
#     117     # shape array
#
# ~/anaconda3/lib/python3.7/site-packages/qibo/core/circuit.py in execute(self, initial_state, nshots)
#     304             return self._repeated_execute(nshots, initial_state)
#     305
# --> 306         state = self._device_execute(initial_state)
#     307         if self.measurement_gate is not None and nshots is not None:
#     308             with self._device():
#
# ~/anaconda3/lib/python3.7/site-packages/qibo/core/circuit.py in _device_execute(self, initial_state)
#     233         try:
#     234             with K.device(device):
# --> 235                 state = self._execute(initial_state=initial_state)
#     236         except K.oom_error:
#     237             raise_error(RuntimeError, f"State does not fit in {device} memory."
#
# ~/anaconda3/lib/python3.7/site-packages/qibo/core/circuit.py in _execute(self, initial_state)
#     219
#     220         if self._compiled_execute is None:
# --> 221             state = self._eager_execute(state)
#     222         else:
#     223             state, callback_results = self._compiled_execute(state)
#
# ~/anaconda3/lib/python3.7/site-packages/qibo/core/circuit.py in _eager_execute(self, state)
#     186         """Simulates the circuit gates in eager mode."""
#     187         for gate in self.queue:
# --> 188             state = gate(state)
#     189         return state
#     190
#
# ~/anaconda3/lib/python3.7/site-packages/qibo/abstractions/abstract_gates.py in __call__(self, state)
#     583             self.substitute_symbols() # pylint: disable=E1101
#     584             # method available only for parametrized gates
# --> 585         return getattr(self, self._active_call)(state)
#
# ~/anaconda3/lib/python3.7/site-packages/qibo/core/gates.py in _state_vector_call(self, state)
#      89
#      90     def _state_vector_call(self, state):
# ---> 91         return K.state_vector_matrix_call(self, state)
#      92
#      93     def _density_matrix_call(self, state):
#
# ~/anaconda3/lib/python3.7/site-packages/qibo/backends/numpy.py in state_vector_matrix_call(self, gate, state)
#     304
#     305     def state_vector_matrix_call(self, gate, state):
# --> 306         return self._state_vector_call(gate, state)
#     307
#     308     def _density_matrix_call(self, gate, state):
#
# ~/anaconda3/lib/python3.7/site-packages/qibo/backends/numpy.py in _state_vector_call(self, gate, state)
#     283     def _state_vector_call(self, gate, state):
#     284         state = self.reshape(state, gate.cache.tensor_shape)
# --> 285         matrix = self.reshape_matrix(gate.native_op_matrix)
#     286         if gate.is_controlled_by:
#     287             ncontrol = len(gate.control_qubits)
#
# ~/anaconda3/lib/python3.7/site-packages/qibo/backends/numpy.py in reshape_matrix(self, matrix)
#     279         """
#     280         rank = int(math.log2(int(matrix.shape[0])))
# --> 281         return self.reshape(matrix, 2 * rank * (2,))
#     282
#     283     def _state_vector_call(self, gate, state):
#
# ~/anaconda3/lib/python3.7/site-packages/qibo/backends/numpy.py in reshape(self, x, shape)
#      58
#      59     def reshape(self, x, shape):
# ---> 60         return self.backend.reshape(x, shape)
#      61
#      62     def stack(self, x, axis=0):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in reshape(tensor, shape, name)
#     194     A `Tensor`. Has the same type as `tensor`.
#     195   """
# --> 196   result = gen_array_ops.reshape(tensor, shape, name)
#     197   tensor_util.maybe_set_static_shape(result, shape)
#     198   return result
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py in reshape(tensor, shape, name)
#    8397     try:
#    8398       return reshape_eager_fallback(
# -> 8399           tensor, shape, name=name, ctx=_ctx)
#    8400     except _core._SymbolicException:
#    8401       pass  # Add nodes to the TensorFlow graph.
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py in reshape_eager_fallback(tensor, shape, name, ctx)
#    8422   _attrs = ("T", _attr_T, "Tshape", _attr_Tshape)
#    8423   _result = _execute.execute(b"Reshape", 1, inputs=_inputs_flat, attrs=_attrs,
# -> 8424                              ctx=ctx, name=name)
#    8425   if _execute.must_record_gradient():
#    8426     _execute.record_gradient(
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# scala logaritmica

# %% [markdown]
# Calculation of the kl divergences: This formula has a problem: if there are bins with no elements the kl divergence diverges, this problem can be solved adding a small quantity at each bin.

# %%
def kl_divergence(bins_real, bins_fake,epsilon):
    
    epsilon=0.1
    prob_real=[]
    prob_fake=[]
    for i in range (len(bins_real)):
        prob_real.append(bins_real[i]+epsilon)
        prob_fake.append(epsilon+bins_fake[i])

    #print(prob_fake,prob_real)  

    prob_real=prob_real/sum(prob_real) # probability for each bin (Normalization)
    prob_fake=prob_fake/sum(prob_fake)

   
    return sum(prob_real[i] * np.log(prob_real[i]/prob_fake[i]) for i in range(len(prob_real)))# Convergence problem if a[i] or b[i] equals zero. 
                                                            #I add a little quantity to each bin to avoid problems


#print(prob_fake,prob_real)
print("KL DIVERGENCE:",kl_divergence(bins_real[0],bins_fake[0],epsilon=0.1))

# %%
data=np.loadtxt('fake_data_6_params.dat')

pyplot.figure(figsize=(14, 7))

bins_data=pyplot.hist(data, bins=bins_real[1],color='red',label='fake_simple_learning', alpha=0.5)
bins_fake=pyplot.hist(x_fake1.numpy(), bins=bins_real[1],color='blue', label='fake_transfer_learning', alpha=0.5)

print("KL DIVERGENCE:",kl_divergence(bins_data[0],bins_fake[0],epsilon=0.1))


pyplot.legend()
pyplot.show()

# %%
# np.savetxt('fake_data.dat',x_fake)
